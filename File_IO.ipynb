# %% [markdown]
# **Practice 1: Modify the following code snippet to produce draw_steps.txt that has the same content as below.**
#
#
#
# ```
# def draw_can_and_write_name(soup_name, can_color):
#   print("I drew a " + can_color + " soup can.")
#   print("I wrote \"" + soup_name + "\" on the can.")
#
# draw_can_and_write_name("chicken noodle soup", "red")
# draw_can_and_write_name("onion soup", "orange")
# draw_can_and_write_name("green pea soup", "green")
# ```

# %%
def draw_can_and_write_name(soup_name, can_color):
  f = open("/content/drive/My Drive/Colab Notebooks/draw_steps.txt", "a")
  f.write("I drew a " + can_color + "soup can.\n")
  f.write("I wrote \"" + soup_name + "\" on the can.\n")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
draw_can_and_write_name("chicken noodle soup", "red")
draw_can_and_write_name("onion soup", "orange")
draw_can_and_write_name("green pea soup", "green")

# %%
f = open("/content/drive/My Drive/Colab Notebooks/draw_steps.txt", "r")
for x in f:
  print(x)
# Out:
# I drew a redsoup can.
#
# I wrote "chicken noodle soup" on the can.
#
# I drew a orangesoup can.
#
# I wrote "onion soup" on the can.
#
# I drew a greensoup can.
#
# I wrote "green pea soup" on the can.

# %% [markdown]
# **draw_steps.txt should contain the following content.**
#
# ![draw_steps_text.png](data:image/png;base64,...)
